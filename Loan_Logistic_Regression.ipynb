# %%
# Import necessary libraries
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %%
#loading the diabetets dataset into a pandas data frames
loan_dataset= pd.read_csv('loan.csv')

# %%
loan_dataset.head() # used to show data structure of data file
# Out:
#    age  gender  occupation education_level marital_status  income  \
# 0   32    Male    Engineer      Bachelor's        Married   85000
# 1   45  Female     Teacher        Master's         Single   62000
# 2   28    Male     Student     High School         Single   25000
# 3   51  Female     Manager      Bachelor's        Married  105000
# 4   36    Male  Accountant      Bachelor's        Married   75000
#
#    credit_score loan_status
# 0           720    Approved
# 1           680    Approved
# 2           590      Denied
# 3           780    Approved
# 4           710    Approved

# %%
print(loan_dataset.shape)
# Out:
# (61, 8)

# %%
loan_dataset['loan_status'].value_counts() # it count number of diabetic patients and number of non diabetic patients
# Out:
# loan_status
# Approved    45
# Denied      16
# Name: count, dtype: int64

# %%
# getting the statistical measure of the data
loan_dataset.describe()
# Out:
#              age         income  credit_score
# count  61.000000      61.000000     61.000000
# mean   37.081967   78983.606557    709.836066
# std     8.424755   33772.025802     72.674888
# min    24.000000   25000.000000    560.000000
# 25%    30.000000   52000.000000    650.000000
# 50%    36.000000   78000.000000    720.000000
# 75%    43.000000   98000.000000    770.000000
# max    55.000000  180000.000000    830.000000

# %%
#loan_dataset.groupby('loan_status').mean()

# %%
loan_dataset.isnull().sum()
# Out:
# age                0
# gender             0
# occupation         0
# education_level    0
# marital_status     0
# income             0
# credit_score       0
# loan_status        0
# dtype: int64

# %%
#loan_dataset
loan_cat = loan_dataset.select_dtypes(include=['object']).copy()
loan_cat.head()
# Out:
#    gender  occupation education_level marital_status loan_status
# 0    Male    Engineer      Bachelor's        Married    Approved
# 1  Female     Teacher        Master's         Single    Approved
# 2    Male     Student     High School         Single      Denied
# 3  Female     Manager      Bachelor's        Married    Approved
# 4    Male  Accountant      Bachelor's        Married    Approved

# %%
loan_cat["occupation"].value_counts()
# Out:
# occupation
# Engineer        5
# Analyst         2
# Chef            2
# Writer          2
# Banker          2
# Receptionist    2
# Teacher         2
# Professor       2
# Designer        2
# Marketing       2
# Salesman        2
# Architect       2
# Consultant      2
# Doctor          2
# IT              2
# Artist          2
# Lawyer          2
# Nurse           2
# Accountant      2
# Manager         2
# Photographer    1
# Server          1
# Psychologist    1
# Software        1
# Musician        1
# Dentist         1
# Programmer      1
# Editor          1
# Pilot           1
# Realtor         1
# Electrician     1
# HR              1
# Sales           1
# Veterinarian    1
# Researcher      1
# Pharmacist      1
# Student         1
# Stylist         1
# Name: count, dtype: int64

# %%
loan_cat["education_level"].value_counts()
# Out:
# education_level
# Bachelor's     23
# Master's       15
# Doctoral       10
# High School     7
# Associate's     6
# Name: count, dtype: int64

# %%
cat_loan = loan_dataset.copy()
cat_loan['gender'] = np.where(cat_loan['gender'].str.contains('Female'), 1, 0)
cat_loan['marital_status'] = np.where(cat_loan['marital_status'].str.contains('Single'), 1, 0)
cat_loan['loan_status'] = np.where(cat_loan['loan_status'].str.contains('Approved'), 1, 0)
#cat_loan['education_level'] = np.where(cat_loan['eductaion_level'].str.contains("Bachelor's"), 1,0)

cat_loan.sample(10)
# Out:
#     age  gender    occupation education_level  marital_status  income  \
# 6    42       0        Lawyer        Doctoral               0  120000
# 57   25       1  Receptionist     High School               1   32000
# 18   30       0    Researcher        Master's               1   72000
# 38   40       0      Software      Bachelor's               0   85000
# 27   43       1            HR        Master's               0   90000
# 22   46       0        Banker        Master's               0  115000
# 43   28       1         Nurse     Associate's               1   50000
# 26   35       0         Sales      Bachelor's               0   70000
# 45   36       1      Engineer        Master's               0   90000
# 1    45       1       Teacher        Master's               1   62000
#
#     credit_score  loan_status
# 6            790            1
# 57           570            0
# 18           700            1
# 38           740            1
# 27           750            1
# ...

# %%
# saperating the data and labels
X = cat_loan.drop(columns = ['loan_status','education_level','occupation'], axis = 1)
Y = cat_loan['loan_status']

# %%
Y.head()
# Out:
# 0    1
# 1    1
# 2    0
# 3    1
# 4    1
# Name: loan_status, dtype: int32

# %%
print(X)
# Out:
#     age  gender  marital_status  income  credit_score
# 0    32       0               0   85000           720
# 1    45       1               1   62000           680
# 2    28       0               1   25000           590
# 3    51       1               0  105000           780
# 4    36       0               0   75000           710
# ..  ...     ...             ...     ...           ...
# 56   39       0               0  100000           770
# 57   25       1               1   32000           570
# 58   43       0               0   95000           760
# 59   30       1               1   55000           650
# 60   38       0               0   65000           700
#
# [61 rows x 5 columns]

# %%
print(Y)
# Out:
# 0     1
# 1     1
# 2     0
# 3     1
# 4     1
#      ..
# 56    1
# 57    0
# 58    1
# 59    1
# 60    1
# Name: loan_status, Length: 61, dtype: int32

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

# %%
scaler.fit(X)
# Out:
# StandardScaler()

# %%
standardized_data = scaler.transform(X) # we can use directly scaler.fix_transform(X)

# %%
print(standardized_data)
# Out:
# [[-6.08224420e-01 -9.83738754e-01 -8.05387266e-01  1.79625673e-01
#    1.41015475e-01]
#  [ 9.47652887e-01  1.01653005e+00  1.24163870e+00 -5.07063209e-01
#   -4.13948653e-01]
#  [-1.08695590e+00 -9.83738754e-01  1.24163870e+00 -1.61173663e+00
#   -1.66261794e+00]
#  [ 1.66575011e+00  1.01653005e+00 -8.05387266e-01  7.76746440e-01
#    9.73461669e-01]
#  [-1.29492941e-01 -9.83738754e-01 -8.05387266e-01 -1.18934710e-01
#    2.27444315e-03]
#  [-1.56568738e+00  1.01653005e+00  1.24163870e+00 -9.25047746e-01
#   -9.68912782e-01]
#  [ 5.88604278e-01 -9.83738754e-01 -8.05387266e-01  1.22458702e+00
#    1.11220270e+00]
#  [-9.67273029e-01  1.01653005e+00  1.24163870e+00 -1.22360813e+00
#   -1.24639485e+00]
#  [-9.81007129e-03 -9.83738754e-01 -8.05387266e-01  3.88617942e-01
#    5.57238572e-01]
#  [ 1.30670150e+00  1.01653005e+00 -8.05387266e-01  3.01594932e+00
#    1.52842580e+00]
#  [ 2.14448158e+00 -9.83738754e-01 -8.05387266e-01  9.26026632e-01
#    8.34720636e-01]
# ...

# %%
X.head()
# Out:
#    age  gender  marital_status  income  credit_score
# 0   32       0               0   85000           720
# 1   45       1               1   62000           680
# 2   28       0               1   25000           590
# 3   51       1               0  105000           780
# 4   36       0               0   75000           710

# %%
X = standardized_data
Y = cat_loan['loan_status']

# %%
print(X)
print(Y)
# Out:
# [[-6.08224420e-01 -9.83738754e-01 -8.05387266e-01  1.79625673e-01
#    1.41015475e-01]
#  [ 9.47652887e-01  1.01653005e+00  1.24163870e+00 -5.07063209e-01
#   -4.13948653e-01]
#  [-1.08695590e+00 -9.83738754e-01  1.24163870e+00 -1.61173663e+00
#   -1.66261794e+00]
#  [ 1.66575011e+00  1.01653005e+00 -8.05387266e-01  7.76746440e-01
#    9.73461669e-01]
#  [-1.29492941e-01 -9.83738754e-01 -8.05387266e-01 -1.18934710e-01
#    2.27444315e-03]
#  [-1.56568738e+00  1.01653005e+00  1.24163870e+00 -9.25047746e-01
#   -9.68912782e-01]
#  [ 5.88604278e-01 -9.83738754e-01 -8.05387266e-01  1.22458702e+00
#    1.11220270e+00]
#  [-9.67273029e-01  1.01653005e+00  1.24163870e+00 -1.22360813e+00
#   -1.24639485e+00]
#  [-9.81007129e-03 -9.83738754e-01 -8.05387266e-01  3.88617942e-01
#    5.57238572e-01]
#  [ 1.30670150e+00  1.01653005e+00 -8.05387266e-01  3.01594932e+00
#    1.52842580e+00]
#  [ 2.14448158e+00 -9.83738754e-01 -8.05387266e-01  9.26026632e-01
#    8.34720636e-01]
# ...

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %%
X_train,X_test,Y_train,Y_test =train_test_split(X,Y, test_size = 0.2,random_state=2) # test_Size 0.2 means testing data set is 20% and trainning dataset is 80%

# %%
print(X.shape, X_train.shape, X_test.shape) # total we have 768 data and we are using 614 number of data as a trainning data and 154 number of data as a testing data
# Out:
# (61, 5) (48, 5) (13, 5)

# %%
print(Y.shape, Y_train.shape, Y_test.shape)
# Out:
# (61,) (48,) (13,)

# %%
from sklearn.linear_model import LogisticRegression
# Train the Logistic Regression model
model = LogisticRegression()
model.fit(X_train, Y_train)
# Out:
# LogisticRegression()

# %%
# Evaluate the model
y_pred = model.predict(X_test)
accuracy = accuracy_score(Y_test, y_pred)
print("Accuracy: {:.2f}%".format(accuracy * 100))
# Out:
# Accuracy: 100.00%

# %%
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# %%
# evaluate the model
print("Confusion Matrix:\n", confusion_matrix(Y_test, y_pred))
print("\nClassification Report:\n", classification_report(Y_test, y_pred))4
# Out:
# Confusion Matrix:
#  [[ 2  0]
#  [ 0 11]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         2
#            1       1.00      1.00      1.00        11
#
#     accuracy                           1.00        13
#    macro avg       1.00      1.00      1.00        13
# weighted avg       1.00      1.00      1.00        13
