# %%
###Data Visualization 
 # Matplotlib , seaborn[fancy cover on matplotlib] , cufflinks[cover on matplotlib]

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.linspace(0,5,11)
x
y = x**2
y
# Out:
# array([ 0.  ,  0.25,  1.  ,  2.25,  4.  ,  6.25,  9.  , 12.25, 16.  ,
#        20.25, 25.  ])

# %%
plt.plot(x,y)
plt.title("Hello")
plt.xlabel("Krena")
plt.ylabel("Shreya")
plt.savefig("figsave.png")

# %%
plt.subplot(2,2,3)
plt.plot(x,y) # after the index 3 
plt.subplot(2,2,1)
plt.subplot(2,2,2)
# Out:
# <Axes: >

# %%
# Matplotlib allows aspect ratio, DPI[clarity] and Figure size

# %%
fig= plt.figure(figsize=(12,8),dpi=400)
axis1 = fig.add_axes([0.1,0.1,0.8,0.8]) #sizes
axis1.plot(x,y)
axis2 = fig.add_axes([0.4,0.4,0.3,0.3]) #sizes
axis2.plot(x,y)

# %%
plt.scatter(x,y)

# %%
plt.hist(y)
# Out:
# (array([4., 1., 1., 1., 1., 0., 1., 0., 1., 1.]),
#  array([ 0. ,  2.5,  5. ,  7.5, 10. , 12.5, 15. , 17.5, 20. , 22.5, 25. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.boxplot(y)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2cc9b987e50>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x2cc9bc60290>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x2cc9bc51b50>],
#  'medians': [<matplotlib.lines.Line2D at 0x2cc9bc612d0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x2cc9bc61ad0>],
#  'means': []}

# %%
import matplotlib.image as mpimg

# %%
img = mpimg.imread('post.jpg')
img #show array of image pixels
plt.imshow(img)
plt.axis('off')
# Out:
# (-0.5, 274.5, 182.5, -0.5)

# %%
plt.plot(x,y,color='pink')

# %%
xaxis = np.linspace(0,5,11)

# %%
fig, ax = plt.subplots(figsize=(12,6))

ax.plot(xaxis, xaxis+1, color="red", linewidth=0.25)
ax.plot(xaxis, xaxis+2, color="red", linewidth=0.50)
ax.plot(xaxis, xaxis+3, color="red", linewidth=1.00)
ax.plot(xaxis, xaxis+4, color="red", linewidth=2.00)

# possible linestype options ‘-‘, ‘–’, ‘-.’, ‘:’, ‘steps’
ax.plot(xaxis, xaxis+5, color="green", lw=3, linestyle='-')
ax.plot(xaxis, xaxis+6, color="green", lw=3, ls='-.')
ax.plot(xaxis, xaxis+7, color="green", lw=3, ls=':')

# custom dash
line, = ax.plot(xaxis, xaxis+8, color="black", lw=1.50)
line.set_dashes([5, 50, 15, 50]) # format: line length, space length, ...

# possible marker symbols: marker = '+', 'o', '*', 's', ',', '.', '1', '2', '3', '4', ...
ax.plot(xaxis, xaxis+ 9, color="blue", lw=3, ls='-', marker='+')
ax.plot(xaxis, xaxis+10, color="blue", lw=3, ls='--', marker='o')
ax.plot(xaxis, xaxis+11, color="blue", lw=3, ls='-', marker='s')
ax.plot(xaxis, xaxis+12, color="blue", lw=3, ls='--', marker='1')
ax.plot(xaxis, xaxis+13, color="purple", lw=1, ls='-', marker='o', markersize=2)
ax.plot(xaxis, xaxis+14, color="purple", lw=1, ls='-', marker='o', markersize=4)
ax.plot(xaxis, xaxis+15, color="purple", lw=1, ls='-', marker='o', markersize=8, markerfacecolor="red")
ax.plot(xaxis, xaxis+16, color="purple", lw=1, ls='-', marker='s', markersize=8, 
        markerfacecolor="yellow", markeredgewidth=3, markeredgecolor="green");

# %%
## SEABORN

# %%
# Distribution plot
# We use distribution plots to visualize the distribution of quantitative data.

# Let's discuss some plots that allow us to visualize the distribution of a data set. These plots are:

# distplot/histplot
# jointplot
# pairplot
# rugplot

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
dset = sns.load_dataset('tips')
dset
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
dset['size'].unique()
# Out:
# array([2, 3, 4, 1, 6, 5], dtype=int64)

# %%
sns.displot(dset['total_bill'])

# %%
plt.subplot(1,2,1)
sns.histplot(dset['total_bill'],bins = 20,kde = True)
plt.subplot(1,2,2)
sns.histplot(dset['tip'],bins = 20,kde = True)
# Out:
# <Axes: xlabel='tip', ylabel='Count'>

# %%
sns.jointplot(x='total_bill',y='tip',data=dset,kind='scatter') #kind[scatter,kde,hex,reg]

# %%
sns.pairplot(dset,hue='size',palette='rainbow')

# %%
sns.rugplot(dset['total_bill'])
# Out:
# <Axes: xlabel='total_bill'>

# %%
## Categorical Data Plots
Now let's discuss using seaborn to plot categorical data! There are a few main plot types for this:

boxplot
violinplot
stripplot
swarmplot
barplot
countplot
Let's go through examples of each!

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = sns.load_dataset('tips')
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.countplot(x= df['sex'],hue=df['smoker'])
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
sns.barplot(x=df['total_bill'],y=df['sex'])
# Out:
# <Axes: xlabel='total_bill', ylabel='sex'>

# %%
import numpy as np

# %%
sns.boxplot(x=df['tip'],y=df['day'])
# Out:
# <Axes: xlabel='tip', ylabel='day'>

# %% [markdown]
# ## boxplot and violinplot
# boxplots and violinplots are used to shown the distribution of categorical data. A box plot (or box-and-whisker plot) shows the distribution of quantitative data in a way that facilitates comparisons between variables or across levels of a categorical variable. The box shows the quartiles of the dataset while the whiskers extend to show the rest of the distribution, except for points that are determined to be “outliers” using a method that is a function of the inter-quartile range.

# %%
sns.violinplot(x=df['day'],y=df['tip'])
# Out:
# <Axes: xlabel='day', ylabel='tip'>

# %%
sns.stripplot(x = 'day',y = 'total_bill',data = df)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.violinplot(x=df['day'],y=df['tip'])
sns.swarmplot(x=df['day'],y=df['tip'])
# Out:
# <Axes: xlabel='day', ylabel='tip'>

# %%
## Matrix plot

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
flights = sns.load_dataset('flights')
flights
# Out:
#      year month  passengers
# 0    1949   Jan         112
# 1    1949   Feb         118
# 2    1949   Mar         132
# 3    1949   Apr         129
# 4    1949   May         121
# ..    ...   ...         ...
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432
#
# [144 rows x 3 columns]

# %%
tips = sns.load_dataset('tips')
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
tipcorr = tips[['total_bill','tip','size']]
tipcorr
# Out:
#      total_bill   tip  size
# 0         16.99  1.01     2
# 1         10.34  1.66     3
# 2         21.01  3.50     3
# 3         23.68  3.31     2
# 4         24.59  3.61     4
# ..          ...   ...   ...
# 239       29.03  5.92     3
# 240       27.18  2.00     2
# 241       22.67  2.00     2
# 242       17.82  1.75     2
# 243       18.78  3.00     2
#
# [244 rows x 3 columns]

# %%
tipcorr.corr()
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
sns.heatmap(tipcorr.corr(),annot=True)
# Out:
# <Axes: >

# %% [markdown]
# ## cluster map

# %%
sns.clustermap(tipcorr.corr(),annot=True)

# %% [markdown]
# ## Pivot table heat map

# %%
pvtflight = flights.pivot_table(values='passengers',index='month',columns='year')
pvtflight
# Out:
# C:\Users\baps\AppData\Local\Temp\ipykernel_14876\3963259204.py:1: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   pvtflight = flights.pivot_table(values='passengers',index='month',columns='year')
# year    1949   1950   1951   1952   1953   1954   1955   1956   1957   1958  \
# month
# Jan    112.0  115.0  145.0  171.0  196.0  204.0  242.0  284.0  315.0  340.0
# Feb    118.0  126.0  150.0  180.0  196.0  188.0  233.0  277.0  301.0  318.0
# Mar    132.0  141.0  178.0  193.0  236.0  235.0  267.0  317.0  356.0  362.0
# Apr    129.0  135.0  163.0  181.0  235.0  227.0  269.0  313.0  348.0  348.0
# May    121.0  125.0  172.0  183.0  229.0  234.0  270.0  318.0  355.0  363.0
# Jun    135.0  149.0  178.0  218.0  243.0  264.0  315.0  374.0  422.0  435.0
# Jul    148.0  170.0  199.0  230.0  264.0  302.0  364.0  413.0  465.0  491.0
# ...

# %%
sns.heatmap(pvtflight)
# Out:
# <Axes: xlabel='year', ylabel='month'>

# %% [markdown]
# ## Regression plot

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
tips = sns.load_dataset('tips')

# %%
sns.lmplot(x = 'total_bill',y = 'tip',data=tips)

# %%
sns.lmplot(x = 'total_bill',y = 'tip',data = tips,hue='sex',palette='coolwarm',markers=['o','v'],scatter_kws={'s':150}) #scatter_kws is size of markers

# %% [markdown]
# ## plotly and cufflinks

# %%
# !pip install plotly
# !pip install cufflinks
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# [notice] A new release of pip is available: 24.3.1 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Defaulting to user installation because normal site-packages is not writeable
# ...
# [notice] A new release of pip is available: 24.3.1 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !pip install cufflinks

import sys
# !{sys.executable} -m pip install cufflinks
# Out:
# ...
#                                               0.0/81.7 kB ? eta -:--:--
#      --------------                         30.7/81.7 kB 660.6 kB/s eta 0:00:01
#      ---------------------------------      71.7/81.7 kB 653.6 kB/s eta 0:00:01
#      -------------------------------------- 81.7/81.7 kB 572.0 kB/s eta 0:00:00
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# ...
#   Created wheel for cufflinks: filename=cufflinks-0.17.3-py3-none-any.whl size=68559 sha256=8cc30a162135b1ae8457fd6559f7f95068e7e990d7699696033e5866f6bc639d
#   Stored in directory: c:\users\baps\appdata\local\pip\cache\wheels\c3\bf\8f\afa0730b29e347e8c1071049f89748c1262e7a14a838820ae6
# Successfully built cufflinks
# ...

# %%
pip install chart_studio
# Out:
# ...
#                                               0.0/64.4 kB ? eta -:--:--
#      ------                                   10.2/64.4 kB ? eta -:--:--
#      ------------------------               41.0/64.4 kB 487.6 kB/s eta 0:00:01
#      -------------------------------------- 64.4/64.4 kB 576.3 kB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.1.2 -> 26.0.1
# [notice] To update, run: C:\Users\baps\AppData\Local\Programs\Python\Python311\python.exe -m pip install --upgrade pip

# %%
import seaborn as sns
import pandas as pd 
import cufflinks as cf 
from plotly.offline import iplot

# %%
tips = sns.load_dataset('tips')
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tips['total_bill'].iplot()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[52], line 1
# ----> 1 tips['total_bill'].iplot()
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\cufflinks\plotlytools.py:1216, in _iplot(self, kind, data, layout, filename, sharing, title, xTitle, yTitle, zTitle, theme, colors, colorscale, fill, width, dash, mode, interpolation, symbol, size, barmode, sortbars, bargap, bargroupgap, bins, histnorm, histfunc, orientation, boxpoints, annotations, keys, bestfit, bestfit_colors, mean, mean_colors, categories, x, y, z, text, gridcolor, zerolinecolor, margin, labels, values, secondary_y, secondary_y_title, subplots, shape, error_x, error_y, error_type, locations, lon, lat, asFrame, asDates, asFigure, asImage, dimensions, asPlot, asUrl, online, **kwargs)
#    1214 	return Figure(figure)
#    1215 else:
# ...

# %%
tips.groupby('day')['tip'].mean().iplot(kind='bar')
# Out:
# C:\Users\baps\AppData\Local\Temp\ipykernel_14876\3886373096.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   tips.groupby('day')['tip'].mean().iplot(kind='bar')
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[51], line 1
# ----> 1 tips.groupby('day')['tip'].mean().iplot(kind='bar')
#
# ...

# %%
tips.iplot(kind='scatter',x ='total_bill',y = 'tip',mode = 'markers')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[53], line 1
# ----> 1 tips.iplot(kind='scatter',x ='total_bill',y = 'tip',mode = 'markers')
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\cufflinks\plotlytools.py:1216, in _iplot(self, kind, data, layout, filename, sharing, title, xTitle, yTitle, zTitle, theme, colors, colorscale, fill, width, dash, mode, interpolation, symbol, size, barmode, sortbars, bargap, bargroupgap, bins, histnorm, histfunc, orientation, boxpoints, annotations, keys, bestfit, bestfit_colors, mean, mean_colors, categories, x, y, z, text, gridcolor, zerolinecolor, margin, labels, values, secondary_y, secondary_y_title, subplots, shape, error_x, error_y, error_type, locations, lon, lat, asFrame, asDates, asFigure, asImage, dimensions, asPlot, asUrl, online, **kwargs)
#    1214 	return Figure(figure)
#    1215 else:
# ...

# %%
tips[['total_bill','day']].iplot(kind = 'box',x = 'total_bill',y = 'day')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[54], line 1
# ----> 1 tips[['total_bill','day']].iplot(kind = 'box',x = 'total_bill',y = 'day')
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\cufflinks\plotlytools.py:1216, in _iplot(self, kind, data, layout, filename, sharing, title, xTitle, yTitle, zTitle, theme, colors, colorscale, fill, width, dash, mode, interpolation, symbol, size, barmode, sortbars, bargap, bargroupgap, bins, histnorm, histfunc, orientation, boxpoints, annotations, keys, bestfit, bestfit_colors, mean, mean_colors, categories, x, y, z, text, gridcolor, zerolinecolor, margin, labels, values, secondary_y, secondary_y_title, subplots, shape, error_x, error_y, error_type, locations, lon, lat, asFrame, asDates, asFigure, asImage, dimensions, asPlot, asUrl, online, **kwargs)
#    1214 	return Figure(figure)
#    1215 else:
# ...
